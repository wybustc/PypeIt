# %%
from pypeit_wrapper import pypeit_wrapper

# %%
ljt= pypeit_wrapper(path_dir = r"D:\ExtractSpec\2M4\251013\251013_test\251013", path_work=r"D:\ExtractSpec\2M4\251013\251013_test", instrument='ljt_yfosc')

# %%
ljt.pypeit_setup()
